# %% [markdown]
# # MongoDB con Python

# %%
# @title Instalación
# !pip install "pymongo[srv]==3.12"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.6/818.6 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 13.2 MB/s eta 0:00:00
# ...
#   Created wheel for pymongo: filename=pymongo-3.12.0-cp311-cp311-linux_x86_64.whl size=510591 sha256=109be34e8256cf647777eee3c7df902f7d4e34203f73bc16d868978c17e56c88
#   Stored in directory: /root/.cache/pip/wheels/0a/e0/8a/adfa1aa746c3a9984d16be698311d2ba894032a3ca7cf400ed
# Successfully built pymongo
# ...

# %%
# @title Librerías de MongoDB
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
# @title Acceso a MongoDB
# Se agregaron los accesos a mi propia cuenta de MongoDB
uri = "mongodb+srv://proinnova:<pass>@cluster0.66yfe65.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Acceso a la base de datos
db = client.proinnova_2025
db
# Out:
# Database(MongoClient(host=['ac-whjnv7z-shard-00-02.66yfe65.mongodb.net:27017', 'ac-whjnv7z-shard-00-01.66yfe65.mongodb.net:27017', 'ac-whjnv7z-shard-00-00.66yfe65.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-cvpjwu-shard-0', ssl=True, server_api=<pymongo.server_api.ServerApi object at 0x7cf5173a3690>), 'proinnova_2025')

# %%
# Prueba de acceso a la collección
collection = db.posts
collection
# Out:
# Collection(Database(MongoClient(host=['ac-whjnv7z-shard-00-02.66yfe65.mongodb.net:27017', 'ac-whjnv7z-shard-00-01.66yfe65.mongodb.net:27017', 'ac-whjnv7z-shard-00-00.66yfe65.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-cvpjwu-shard-0', ssl=True, server_api=<pymongo.server_api.ServerApi object at 0x7cf5173a3690>), 'proinnova_2025'), 'posts')

# %% [markdown]
# ### Inserción de datos a la **colección**

# %% [markdown]
# **Un objeto**

# %%
import datetime
post = {
    "author": "Fernando",
    "text": "Haciendo pruebas",
    "tags": ["mongodb", "python", "pymongo", "R"],
    "date": datetime.datetime(2025, 7, 7, 11, 14)
}
post
# Out:
# {'author': 'Fernando',
#  'text': 'Haciendo pruebas',
#  'tags': ['mongodb', 'python', 'pymongo', 'R'],
#  'date': datetime.datetime(2025, 7, 7, 11, 14)}

# %%
posts = db.posts
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('686c015b58db1848454014fe')

# %%
db.list_collection_names()
# Out:
# ['posts']

# %% [markdown]
# **Consultar e imprimir objeto**

# %%
import pprint
#pprint.pprint(posts.find_one())
pprint.pprint(posts.find_one({'author':'Fernando'}))
# Out:
# {'_id': ObjectId('686c015b58db1848454014fe'),
#  'author': 'Fernando',
#  'date': datetime.datetime(2025, 7, 7, 11, 14),
#  'tags': ['mongodb', 'python', 'pymongo', 'R'],
#  'text': 'Haciendo pruebas'}

# %% [markdown]
# **Múltiples objetos**

# %%
new_posts = [
    {
        "author": "Mike",
        "text": "Another post!",
        "tags": ["bulk", "insert"],
        "date": datetime.datetime(2009, 11, 12, 11, 14),
    },
    {
        "author": "Eliot",
        "title": "MongoDB is fun",
        "text": "and pretty easy too!",
        "date": datetime.datetime(2009, 11, 10, 10, 45),
    },
]
result = posts.insert_many(new_posts)
result.inserted_ids
# Out:
# [ObjectId('686bffc758db1848454014fb'), ObjectId('686bffc758db1848454014fc')]
