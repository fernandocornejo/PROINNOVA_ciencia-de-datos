# %% [markdown]
# # Lectura de datos de otras fuentes
# - Excel
# - API
# - Texto

# %%
import pandas as pd

alumnos = pd.read_excel("/content/Análisis y ciencias de datos con Python.xlsx")
alumnos.columns
# Out:
# Index(['No.', 'Código de trabajador', 'Apellido Paterno', 'Apellido Materno',
#        'Nombre(s)', 'Nombre completo', 'Grado académico', 'Dependencia',
#        'Correo institucional', 'Correo personal', 'Nombramiento',
#        'Departamento o área de adscripción'],
#       dtype='object')

# %%
alumnos = alumnos[['No.', 'Apellido Paterno', 'Apellido Materno',
       'Nombre(s)', 'Nombre completo', 'Grado académico']]
alumnos.head()
# Out:
#    No. Apellido Paterno Apellido Materno        Nombre(s)  \
# 0    1          Aguirre           Alcalá  Rubén Magdaleno
# 1    2          Álvarez            Marín           Carlos
# 2    3            Anaya         Esparaza      Luis Miguel
# 3    4        Contreras          Pacheco  Yéssica Vanessa
# 4    5          Cornejo        Gutiérrez         Fernando
#
#                      Nombre completo Grado académico
# 0     Aguirre Alcalá Rubén Magdaleno        Maestría
# 1               Álvarez Marín Carlos        Maestría
# 2         Anaya Esparaza Luis Miguel       Doctorado
# 3  Contreras Pacheco Yéssica Vanessa       Doctorado
# 4         Cornejo Gutiérrez Fernando        Maestría

# %% [markdown]
# ## Funciones **try-except**
#
# https://docs.python.org/es/3.13/tutorial/errors.html

# %%
import requests

url = "https://api.github.com/repos/requests/requests"

try:
    headers = {
        "User-Agent": "MyPythonApp/1.0",
        "Accept": "application/vnd.github.v3+json"
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status()

    repo_data = response.json()

    print("GitHub Repository Info:")
    print(f"Name: {repo_data['name']}")
    print(f"Description: {repo_data['description']}")
    print(f"Stars: {repo_data['stargazers_count']}")
    print(f"Forks: {repo_data['forks_count']}")

except requests.exceptions.RequestException as e:
    print(f"Error fetching GitHub data: {e}")
# Out:
# GitHub Repository Info:
# Name: requests
# Description: A simple, yet elegant, HTTP library.
# Stars: 53010
# Forks: 9497

# %%
import yfinance as yf

byd = yf.download("BYD", "2020-01-01")
byd
# Out:
# /tmp/ipython-input-1-3288598457.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   byd = yf.download("BYD", "2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume
# Ticker            BYD        BYD        BYD        BYD      BYD
# Date
# 2020-01-02  28.954132  29.137204  28.530179  29.117933   926600
# 2020-01-03  28.597626  28.693979  28.298931  28.549448   557400
# 2020-01-06  28.645802  28.828873  27.913517  28.019506   771900
# 2020-01-07  28.453098  28.636168  28.366380  28.539816   554000
# 2020-01-08  28.703615  28.915592  28.472366  28.472366   479200
# 2020-01-09  28.530176  28.867411  28.472363  28.838506   349800
# 2020-01-10  27.595552  28.404919  27.364305  28.376015  1435400
# 2020-01-13  27.634092  27.759351  27.190867  27.595550   705400
# 2020-01-14  27.768991  28.009874  27.489568  27.682273   615500
# 2020-01-15  28.250757  28.337475  27.624462  27.624462   983400
# 2020-01-16  28.742155  28.896320  28.424190  28.462732   645100
# 2020-01-17  28.192942  28.886684  27.980965  28.838508   634700
# 2020-01-21  27.508833  28.086952  27.441386  27.942423   672600
# 2020-01-22  27.383579  27.836439  27.383579  27.740087   777900
# 2020-01-23  28.135134  28.173674  26.670565  27.046342   864600
# 2020-01-24  28.433826  28.559085  27.903883  28.279661  1445900
# 2020-01-27  27.730453  28.144771  27.364310  27.547382  1283100
# 2020-01-28  28.587990  28.838508  27.788258  27.942423  1055700
# 2020-01-29  28.742155  29.195014  28.221849  28.674708   839600
# 2020-01-30  29.753862  29.802040  28.308565  28.395283  1414800
# 2020-01-31  28.761427  29.994747  28.684344  29.696052  1067100

# %% [markdown]
# ## Texto con funcion **with** y **open**
#
# https://www.w3schools.com/python/python_file_open.asp

# %%
with open('zen.txt', 'r', encoding='utf-8') as file:
    content = file.read()

# %%
content
# Out:
# "The Zen of Python, by Tim Peters\n\nBeautiful is better than ugly.\nExplicit is better than implicit.\nSimple is better than complex.\nComplex is better than complicated.\nFlat is better than nested.\nSparse is better than dense.\nReadability counts.\nSpecial cases aren't special enough to break the rules.\nAlthough practicality beats purity.\nErrors should never pass silently.\nUnless explicitly silenced.\nIn the face of ambiguity, refuse the temptation to guess.\nThere should be one-- and preferably only one --obvious way to do it.\nAlthough that way may not be obvious at first unless you're Dutch.\nNow is better than never.\nAlthough never is often better than *right* now.\nIf the implementation is hard to explain, it's a bad idea.\nIf the implementation is easy to explain, it may be a good idea.\nNamespaces are one honking great idea -- let's do more of those!"

# %%
with open('zen.txt', 'r') as file:
    for line in file:
        print(line, end='')
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
